# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from tqdm import tqdm

# %%
df = pd.read_csv("data/preprocessed_train.csv")
df
# Out:
#                            img_id  complexity  \
# 0       clb0kvxvm90y4074yf50vf5nq           3
# 1       cl8k2u1r71foz083278j63qnm           2
# 2       cl8k2u1qa1ekz08324rek2qcv           3
# 3       cla820gmss67b071u3h7o5k3t           3
# 4       clb0kvxvf90l4074y85pi02pq           1
# ...                           ...         ...
# 143589  clb0lbwybdnz8086u24pid7l7           1
# 143590  clb0lbx03dpyg086u4g58d4qc           2
# 143591  clb0kvxwp92k8074ybz5l790g           1
# 143592  clb0kvxwo92hs074y8p8h4lm3           2
# 143593  cl8k2u1rj1g8z0832bqte1znp           2
#
#                                                  question  \
# 0       Are there any abnormalities, polyps, or anatom...
# 1       What procedure is depicted in the image and wh...
# 2       Have all polyps been removed, is there any tex...
# 3       Are there any surgical instruments, polyps, or...
# 4       Are there any medical devices visible in the i...
# ...                                                   ...
# 143589           What procedure is depicted in the image?
# 143590  Are there any green or black box artifacts and...
# 143591  In which regions of the image is the abnormali...
# 143592  Identify the anatomical landmark and assess fo...
# 143593  Has there been complete removal of all polyps ...
#
#                                                    answer  \
# 0       Evidence of oesophagitis is present with no po...
# 1       Evidence of a colonoscopy with a paris iia pol...
# 2       Polyps remain present, text is visible, and th...
# 3       No surgical instruments or polyps are visible,...
# 4             No foreign bodies or instruments identified
# ...                                                   ...
# 143589                  evidence of colonoscopy procedure
# 143590  evidence of green and black box artifacts with...
# 143591  scattered across multiple quadrants including ...
# 143592  No anatomical landmark identified, with eviden...
# 143593  Residual polyps are present and the abnormalit...
#
#                                                  original  \
# 0       [\n{\n"q": "Are there any abnormalities in the...
# 1       [\n{\n"q": "What type of procedure is the imag...
# 2       [\n{\n"q": "Have all polyps been removed?",\n"...
# 3       [\n{\n"q": "How many instrumnets are in the im...
# 4       [\n{\n"q": "Are there any instruments in the i...
# ...                                                   ...
# 143589  [\n{\n"q": "What type of procedure is the imag...
# 143590  [\n{\n"q": "Is there a green/black box artefac...
# 143591  [\n{\n"q": "Where in the image is the abnormal...
# 143592  [\n{\n"q": "Where in the image is the anatomic...
# 143593  [\n{\n"q": "Have all polyps been removed?",\n"...
#
#                                            question_class  \
# 0       ['abnormality_presence', 'polyp_type', 'landma...
# 1                        ['procedure_type', 'polyp_type']
# 2       ['polyp_removal_status', 'text_presence', 'abn...
# 3       ['instrument_count', 'polyp_count', 'finding_c...
# 4                                 ['instrument_presence']
# ...                                                   ...
# 143589                                 ['procedure_type']
# 143590         ['box_artifact_presence', 'text_presence']
# 143591                           ['abnormality_location']
# 143592      ['landmark_location', 'abnormality_presence']
# 143593      ['polyp_removal_status', 'abnormality_color']
#
#                                             norm_question  \
# 0       are there any abnormalities polyps or anatomic...
# 1       what procedure is depicted in the image and wh...
# 2       have all polyps been removed is there any text...
# 3       are there any surgical instruments polyps or a...
# 4       are there any medical devices visible in the i...
# ...                                                   ...
# 143589            what procedure is depicted in the image
# 143590  are there any green or black box artifacts and...
# 143591  in which regions of the image is the abnormali...
# 143592  identify the anatomical landmark and assess fo...
# 143593  has there been complete removal of all polyps ...
#
#                                               dl_question  \
# 0       any abnormality polyp anatomical landmark visi...
# 1       what procedure depicted image what type polyp ...
# 2       polyp removed any text present where abnormali...
# 3       any surgical instrument polyp abnormal finding...
# 4                        any medical device visible image
# ...                                                   ...
# 143589                      what procedure depicted image
# 143590    any green black box artifact visible text image
# 143591                   region image abnormality located
# 143592  identify anatomical landmark assess any abnorm...
# 143593      complete removal polyp what color abnormality
#
#                                               norm_answer
# 0       evidence of oesophagitis is present with no po...
# 1       evidence of a colonoscopy with a paris iia pol...
# 2       polyps remain present text is visible and the ...
# 3       no surgical instruments or polyps are visible ...
# 4             no foreign bodies or instruments identified
# ...                                                   ...
# 143589                  evidence of colonoscopy procedure
# 143590  evidence of green and black box artifacts with...
# 143591  scattered across multiple quadrants including ...
# 143592  no anatomical landmark identified with evidenc...
# 143593  residual polyps are present and the abnormalit...
#
# [143594 rows x 9 columns]

# %%
from gensim.models import Word2Vec
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
import nltk
import re

def download_nltk():
    nltk.download('stopwords')
    nltk.download('wordnet')
    nltk.download("punkt")
    nltk.download("omw-1.4")

sort_dict = lambda x: dict(reversed(sorted(x.items(), key=lambda item: item[1])))

def norm_text(text, keep_num = False):
    text = text.lower()
    
    text = text.replace("/", " ")
    text = text.replace("?", "")
    
    if not keep_num:
        text = re.sub(r"\d+", "", text)
    
    text = re.sub(r"[^a-zA-Z.,!?;:\s]", "", text)

    text = " ".join(text.split())
    return text

# to deep learning format (remove stopwords + lemmatize)
def to_deep_learning(text):
    stop_words = set(stopwords.words("english"))
    white_list = ["what", "when", "where", "why", "any", "how", "if", "more"]
    stop_words.difference_update(white_list)
    
    words = re.findall(r"\w+|[.,!?;:]", text)
    words = [w for w in words if w not in stop_words]
    
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(w) for w in words]
    
    stemmer = PorterStemmer()
    words = [stemmer.stem(w) for w in words]
    
    return " ".join(words)

class Tokenizer:
    # get <vocab_size> most occur words
    def __init__(self, vocab_size, max_length):
        self.vocab_size = vocab_size
        self.max_length = max_length
        self.vocab_map = dict({})
        
        self.cls_id = None
        self.sep_id = None
        self.unknown_id = None
        self.pad_id = 0
        
    def fit_transform(self, data, pad = "pre", truncation = "post"):
        tokens = list(map(lambda s: s.split(), data))
        word_counts = dict({})
        
        sep_vocab = [",", ".", "?", "!", ";", ":"]
        
        for sentence in tokens:
            for word in sentence:
                if word not in sep_vocab:
                    word_counts[word] = word_counts.get(word, 0) + 1

        word_counts = sort_dict(word_counts)
        vocab = list(word_counts.keys())[:self.vocab_size:]
        self.vocab_size = len(vocab)
        self.vocab_map = {w: i for w, i in zip(vocab, range(1, self.vocab_size + 1))}
        
        self.unknown_id = self.vocab_size + 1
        self.cls_id = self.unknown_id + 1
        self.sep_id = self.cls_id + 1
        
        ids = []
        for sentence in tokens:
            tmp = [self.cls_id]
            for word in sentence:
                if word in sep_vocab:
                    id = self.sep_id
                else:
                    id = self.vocab_map.get(word, self.unknown_id)
                tmp.append(id)
            tmp.append(self.sep_id)
            ids.append(tmp)
            
        for i, sentence in enumerate(ids):
            if len(sentence) > self.max_length:
                if truncation == "pre":
                    ids[i] = ids[i][-self.max_length::]
                elif truncation == "post":
                    ids[i] = ids[i][:self.max_length:]
            else:
                pad_len = self.max_length - len(sentence)
                if pad == "pre":
                    ids[i] = [self.pad_id] * pad_len + ids[i]
                elif pad == "post":
                    ids[i] = ids[i] + [self.pad_id] * pad_len
            
        return ids

# %%
texts = df["question"].apply(lambda x: to_deep_learning(norm_text(x)))

# %%
texts = texts.to_list()

# %%
tokenizer = Tokenizer(1000, 100)
ids = tokenizer.fit_transform(texts)

# %%
ids = np.array(ids)

# %%
ids.max()
# Out:
# 352

# %%
tokenizer.vocab_map
# Out:
# {'imag': 1,
#  'ani': 2,
#  'what': 3,
#  'visibl': 4,
#  'polyp': 5,
#  'present': 6,
#  'abnorm': 7,
#  'instrument': 8,
#  'how': 9,
#  'mani': 10,
#  'locat': 11,
#  'where': 12,
#  'type': 13,
#  'landmark': 14,
#  'anatom': 15,
#  'procedur': 16,
#  'black': 17,
#  'green': 18,
#  'text': 19,
#  'box': 20,
#  'color': 21,
#  'find': 22,
#  'observ': 23,
#  'size': 24,
#  'remov': 25,
#  'artifact': 26,
#  'artefact': 27,
#  'perform': 28,
#  'depict': 29,
#  'remain': 30,
#  'gastrointestin': 31,
#  'area': 32,
#  'identifi': 33,
#  'evid': 34,
#  'region': 35,
#  'medic': 36,
#  'surgic': 37,
#  'if': 38,
#  'obtain': 39,
#  'seen': 40,
#  'tract': 41,
#  'complet': 42,
#  'tissu': 43,
#  'element': 44,
#  'check': 45,
#  'boxlik': 46,
#  'distinct': 47,
#  'textual': 48,
#  'associ': 49,
#  'number': 50,
#  'relev': 51,
#  'shown': 52,
#  'residu': 53,
#  'sign': 54,
#  'ulcer': 55,
#  'coliti': 56,
#  'presenc': 57,
#  'excis': 58,
#  'detect': 59,
#  'taken': 60,
#  'content': 61,
#  'inform': 62,
#  'confirm': 63,
#  'contain': 64,
#  'statu': 65,
#  'colon': 66,
#  'within': 67,
#  'lesion': 68,
#  'use': 69,
#  'oesophag': 70,
#  'boxshap': 71,
#  'success': 72,
#  'indic': 73,
#  'specif': 74,
#  'foreign': 75,
#  'natur': 76,
#  'show': 77,
#  'devic': 78,
#  'includ': 79,
#  'characterist': 80,
#  'multipl': 81,
#  'esophag': 82,
#  'bodi': 83,
#  'note': 84,
#  'achiev': 85,
#  'examin': 86,
#  'account': 87,
#  'patient': 88,
#  'pleas': 89,
#  'signific': 90,
#  'repres': 91,
#  'inflamm': 92,
#  'visual': 93,
#  'diagnosi': 94,
#  'diseas': 95,
#  'inflammatori': 96,
#  'undergon': 97,
#  'total': 98,
#  'bowel': 99,
#  'zline': 100,
#  'everi': 101,
#  'along': 102,
#  'applic': 103,
#  'address': 104,
#  'polypoid': 105,
#  'classif': 106,
#  'patholog': 107,
#  'assess': 108,
#  'describ': 109,
#  'count': 110,
#  'determin': 111,
#  'current': 112,
#  'list': 113,
#  'largest': 114,
#  'detail': 115,
#  'measur': 116,
#  'captur': 117,
#  'addit': 118,
#  'one': 119,
#  'part': 120,
#  'tube': 121,
#  'context': 122,
#  'specifi': 123,
#  'object': 124,
#  'rang': 125,
#  'polypectomi': 126,
#  'condit': 127,
#  'dimens': 128,
#  'document': 129,
#  'exhibit': 130,
#  'sourc': 131,
#  'singl': 132,
#  'issu': 133,
#  'incomplet': 134,
#  'follow': 135,
#  'separ': 136,
#  'more': 137,
#  'appear': 138,
#  'kind': 139,
#  'structur': 140,
#  'display': 141,
#  'variat': 142,
#  'demonstr': 143,
#  'barrett': 144,
#  'concern': 145,
#  'well': 146,
#  'found': 147,
#  'posit': 148,
#  'still': 149,
#  'cecum': 150,
#  'pertin': 151,
#  'endoscop': 152,
#  'colonoscopi': 153,
#  'annot': 154,
#  'readabl': 155,
#  'affect': 156,
#  'view': 157,
#  'across': 158,
#  'exactli': 159,
#  'appli': 160,
#  'mention': 161,
#  'distribut': 162,
#  'like': 163,
#  'fulli': 164,
#  'requir': 165,
#  'central': 166,
#  'involv': 167,
#  'featur': 168,
#  'studi': 169,
#  'overal': 170,
#  'relat': 171,
#  'regard': 172,
#  'whether': 173,
#  'materi': 174,
#  'differ': 175,
#  'referenc': 176,
#  'prior': 177,
#  'absenc': 178,
#  'esophagu': 179,
#  'quantiti': 180,
#  'case': 181,
#  'retain': 182,
#  'diamet': 183,
#  'character': 184,
#  'variou': 185,
#  'lowercent': 186,
#  'situat': 187,
#  'instanc': 188,
#  'pari': 189,
#  'center': 190,
#  'chang': 191,
#  'techniqu': 192,
#  'field': 193,
#  'mucos': 194,
#  'accomplish': 195,
#  'upper': 196,
#  'acquir': 197,
#  'base': 198,
#  'growth': 199,
#  'also': 200,
#  'consider': 201,
#  'absent': 202,
#  'exist': 203,
#  'diagnost': 204,
#  'unresect': 205,
#  'need': 206,
#  'left': 207,
#  'uppercent': 208,
#  'centerright': 209,
#  'previou': 210,
#  'consid': 211,
#  'lowerright': 212,
#  'origin': 213,
#  'diagnos': 214,
#  'may': 215,
#  'key': 216,
#  'refer': 217,
#  'suggest': 218,
#  'centerleft': 219,
#  'behind': 220,
#  'lowerleft': 221,
#  'millimet': 222,
#  'mm': 223,
#  'unremov': 224,
#  'adequ': 225,
#  'pink': 226,
#  'red': 227,
#  'mark': 228,
#  'shortseg': 229,
#  'metal': 230,
#  'forcep': 231,
#  'biopsi': 232,
#  'larger': 233,
#  'snare': 234,
#  'tool': 235,
#  'ip': 236,
#  'notabl': 237,
#  'larg': 238,
#  'unresolv': 239,
#  'evalu': 240,
#  'histopatholog': 241,
#  'interest': 242,
#  'given': 243,
#  'deriv': 244,
#  'upperleft': 245,
#  'primari': 246,
#  'attent': 247,
#  'upperright': 248,
#  'intestin': 249,
#  'free': 250,
#  'necessari': 251,
#  'gastroscopi': 252,
#  'two': 253,
#  'lower': 254,
#  'defin': 255,
#  'correspond': 256,
#  'vari': 257,
#  'written': 258,
#  'classifi': 259,
#  'resect': 260,
#  'suspect': 261,
#  'term': 262,
#  'zero': 263,
#  'ileum': 264,
#  'result': 265,
#  'maximum': 266,
#  'clip': 267,
#  'iia': 268,
#  'multiplecolor': 269,
#  'piec': 270,
#  'provid': 271,
#  'site': 272,
#  'clinic': 273,
#  'record': 274,
#  'white': 275,
#  'peripher': 276,
#  'review': 277,
#  'manifest': 278,
#  'rel': 279,
#  'occupi': 280,
#  'histolog': 281,
#  'morpholog': 282,
#  'placement': 283,
#  'colour': 284,
#  'compos': 285,
#  'sizeabl': 286,
#  'paristyp': 287,
#  'less': 288,
#  'descript': 289,
#  'name': 290,
#  'identif': 291,
#  'colonoscop': 292,
#  'equip': 293,
#  'intervent': 294,
#  'potenti': 295,
#  'state': 296,
#  'abdomin': 297,
#  'attempt': 298,
#  'undiagnos': 299,
#  'place': 300,
#  'treatment': 301,
#  'polyplik': 302,
#  'without': 303,
#  'colorect': 304,
#  'smaller': 305,
#  'uppercentr': 306,
#  'clear': 307,
#  'textrel': 308,
#  'previous': 309,
#  'properli': 310,
#  'none': 311,
#  'occurr': 312,
#  'recogn': 313,
#  'quantifi': 314,
#  'tubelik': 315,
#  'artifactrel': 316,
#  'compris': 317,
#  'consist': 318,
#  'fragment': 319,
#  'conduct': 320,
#  'would': 321,
#  'scatter': 322,
#  'nonrelev': 323,
#  'spatial': 324,
#  'when': 325,
#  'pinkcolor': 326,
#  'irregular': 327,
#  'tubular': 328,
#  'certain': 329,
#  'highlight': 330,
#  'remnant': 331,
#  'surround': 332,
#  'exact': 333,
#  'anomali': 334,
#  'three': 335,
#  'hemorrhoid': 336,
#  'full': 337,
#  'mass': 338,
#  'report': 339,
#  'underli': 340,
#  'appropri': 341,
#  'discolor': 342,
#  'clarif': 343,
#  'sizerel': 344,
#  'action': 345,
#  'occur': 346,
#  'yet': 347,
#  'needl': 348,
#  'inject': 349}

# %%
import pickle
with open("models/tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)
